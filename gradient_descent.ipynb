# %%
import numpy as np

# %%
def gradient_descent(x, y):
    m_curr = b_curr = 0
    iterations = 10000 #how many baby steps we are going to do
    n = len(x)
    learning_rate = 0.08 #how big of a step we are taking
    
    for i in range(iterations):
        y_predicted = m_curr * x + b_curr
        cost = (1/n)*sum([val**2 for val in (y-y_predicted)])
        m_derivative = -(2/n)*sum(x*(y - y_predicted))
        b_derivative = -(2/n)*sum(y - y_predicted)
        m_curr = m_curr - learning_rate * m_derivative
        b_curr = b_curr - learning_rate * b_derivative
        print("m {}, b{}, cost {}, iteration {}".format(m_curr, b_curr, cost, i))

# %%
x = np.array([1, 2, 3, 4, 5])
y = np.array([5, 7, 8, 11, 13])

gradient_descent(x, y)
# Out:
# m 4.864000000000001, b1.4080000000000001, cost 85.60000000000001, iteration 0
# m 0.4915199999999986, b0.25599999999999956, cost 68.40499200000006, iteration 1
# m 4.367564800000001, b1.3871104000000005, cost 54.688005734400065, iteration 2
# m 0.8788377599999984, b0.47674163199999975, cost 43.74460482650118, iteration 3
# m 3.967247319040002, b1.3866208460800007, cost 35.01307923269583, iteration 4
# m 1.1833140314111983, b0.6684827975679997, cost 28.045524681689564, iteration 5
# m 3.6438095932948498, b1.4015348148797444, cost 22.48478241464289, iteration 6
# m 1.4219679979536362, b0.8362606397174573, cost 18.046051719946202, iteration 7
# m 3.381899214490857, b1.427914298344919, cost 14.502228387938079, iteration 8
# m 1.6083577337813872, b0.9841363876541205, cost 11.672214081813486, iteration 9
# m 3.169262656252168, b1.4626628534143955, cost 9.411594611917527, iteration 10
# m 1.7532822116094424, b1.1153907218670516, cost 7.605207090074086, iteration 11
# ...
